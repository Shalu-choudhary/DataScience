# %%
import pandas as pd
print(" i am executed")
# Out:
#  i am executed

# %%
dt={'name':['shalu','monika','chanchal','suman'],'city':['Ajmer','jaipur','jodhpur','kekdi'],'age':[20,23,25,27]}
dt
# Out:
# {'name': ['shalu', 'monika', 'chanchal', 'suman'],
#  'city': ['Ajmer', 'jaipur', 'jodhpur', 'kekdi'],
#  'age': [20, 23, 25, 27]}

# %%
df=pd.DataFrame(dt)
df
# Out:
#        name     city  age
# 0     shalu    Ajmer   20
# 1    monika   jaipur   23
# 2  chanchal  jodhpur   25
# 3     suman    kekdi   27

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dt['name']
# Out:
# ['shalu', 'monika', 'chanchal', 'suman']

# %%
df['name']
# Out:
# 0       shalu
# 1      monika
# 2    chanchal
# 3       suman
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
#csv files--?
df=pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
# df.price
df['age']
df[['price','city']]
# Out:
#           price       city
# 0       35000.0  Ahmedabad
# 1      119900.0      Delhi
# 2      600000.0      Delhi
# 3       65000.0  Bangalore
# 4       80000.0  Bangalore
# ...         ...        ...
# 32643   39000.0      Delhi
# 32644   30000.0     Karnal
# 32645   60000.0      Delhi
# 32646   15600.0     Jaipur
# 32647   22000.0       Pune
#
# [32648 rows x 2 columns]

# %%
# loc--> specific colmn or row index,co label
loc=df.loc[100:111,['city','price','brand']]
loc
# Out:
#           city     price          brand
# 100      Delhi   68000.0          Honda
# 101  Bangalore   80000.0          Bajaj
# 102  Bangalore  135000.0  Royal Enfield
# 103       Pune   11100.0          Bajaj
# 104     Mumbai  480000.0        Benelli
# 105   Thrissur   65000.0         Suzuki
# 106  Bangalore   60000.0         Yamaha
# 107  Bangalore   80000.0          Honda
# 108      Delhi   46000.0           Hero
# 109  Bangalore   95000.0  Royal Enfield
# 110      Delhi  400000.0        Hyosung
# 111  Bangalore   55000.0          Bajaj

# %%
df.loc[121:150,['price','city','owner']]
# Out:
#         price       city         owner
# 121   48672.0  Ernakulam   First Owner
# 122   40000.0     Mumbai   First Owner
# 123  500000.0  Bangalore   First Owner
# 124  800000.0     Mumbai   First Owner
# 125  110000.0  Bangalore   First Owner
# 126   92500.0      Delhi   First Owner
# 127   57000.0  Bangalore   First Owner
# 128   72500.0      Delhi   First Owner
# 129   68000.0      Delhi   First Owner
# 130   21500.0    Barasat   First Owner
# 131   40000.0      Delhi   First Owner
# 132   91000.0      Delhi   First Owner
# 133  300000.0  Ghaziabad   First Owner
# 134   47000.0     Jaipur   First Owner
# 135   53000.0  Bangalore   First Owner
# 136   51000.0  Bangalore   First Owner
# 137   48000.0  Bangalore   First Owner
# 138   55000.0  Bangalore   First Owner
# 139  173300.0   Vadodara   First Owner
# 140   77000.0      Delhi   First Owner
# 141  115000.0  Bangalore   First Owner
# 142   36000.0  Hyderabad   First Owner
# 143   72000.0  Hyderabad   First Owner
# ...

# %%
df.iloc[120:130,2:7]
# Out:
#           city  kms_driven        owner   age   power
# 120  Ernakulam     51576.0  First Owner   6.0   100.0
# 121  Ernakulam       608.0  First Owner   2.0   110.0
# 122     Mumbai     13680.0  First Owner   9.0   150.0
# 123  Bangalore       285.0  First Owner   5.0   600.0
# 124     Mumbai         3.0  First Owner   3.0  1299.0
# 125  Bangalore     24676.0  First Owner   5.0   410.0
# 126      Delhi     11000.0  First Owner   6.0   350.0
# 127  Bangalore     28948.0  First Owner   5.0   200.0
# 128      Delhi     10000.0  First Owner  10.0   350.0
# 129      Delhi     16000.0  First Owner   9.0   200.0

# %%
df.iloc[:5,::]
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.price.max()
# Out:
# np.float64(1900000.0)

# %%
df.price.min()
# Out:
# np.float64(4400.0)

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.columns=['bike_name', 'charges', 'city', 'kms_driven', 'owner', 'age', 'power',
       'brand_name']

# %%
df.columns
# Out:
# Index(['bike_name', 'charges', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand_name'],
#       dtype='object')

# %%
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.dtypes
# Out:
# bike_name      object
# charges       float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand_name     object
# dtype: object

# %%
under50k=df[df['charges']<=50000]
under50k
# Out:
#                                  bike_name  charges         city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0        Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0        Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0        Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0       Mumbai     24725.0
# ...                                    ...      ...          ...         ...
# 32642                   Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643               Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power brand_name
# ...

# %%
under50k.head().max()
# Out:
# bike_name     TVS Star City Plus Dual Tone 110cc
# charges                                  48000.0
# city                                      Mumbai
# kms_driven                               24725.0
# owner                                First Owner
# age                                          8.0
# power                                      150.0
# brand_name                                   TVS
# dtype: object

# %%
under50k['owner'].value_counts()
# Out:
# owner
# First Owner             17447
# Second Owner             1604
# Third Owner                57
# Fourth Owner Or More        6
# Name: count, dtype: int64

# %%
first=under50k[under50k['owner']=="First Owner"]
first
# Out:
#                                  bike_name  charges       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
# ...                                    ...      ...        ...         ...
# 32640               Hero Passion Pro 100cc  32000.0      Delhi     12000.0
# 32643               Hero Passion Pro 100cc  39000.0      Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0     Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0       Pune     60857.0
#
#              owner   age  power brand_name
# ...

# %%
first['charges'].min()
# Out:
# np.float64(4400.0)

# %%
first['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj            6356
# Hero             5541
# Yamaha           2187
# Suzuki           1286
# Honda            1131
# TVS               905
# Mahindra           27
# Royal Enfield      13
# LML                 1
# Name: count, dtype: int64

# %%
first['brand_name'].unique()
# Out:
# array(['TVS', 'Hero', 'Bajaj', 'Suzuki', 'Yamaha', 'Honda', 'Mahindra',
#        'Royal Enfield', 'LML'], dtype=object)

# %%
first['brand_name'].nunique()
# Out:
# 9

# %%
df['charges'].unique()
# Out:
# array([ 35000., 119900., 600000., ...,  65450.,  11400.,  61483.])

# %%
df['city'].nunique()
# Out:
# 443

# %%
df[(df['charges']<100000)&(df['owner']=="First Owner")&(df['age']<=2)]
# Out:
#                                 bike_name  charges       city  kms_driven  \
# 22    Hero Splendor iSmart Plus IBS 110cc  46500.0      Delhi      3500.0
# 29                Honda X-Blade 160CC ABS  81200.0     Mettur      9100.0
# 47             Mahindra Centuro NXT 110cc  28000.0     Jaipur     45000.0
# 95                     Bajaj Pulsar 150cc  60000.0       Pune      2000.0
# 96             Suzuki Gixxer Fi 150cc ABS  96700.0   Vadodara      5100.0
# ...                                   ...      ...        ...         ...
# 8335              Bajaj Pulsar 150cc Neon  72000.0       Pune      3162.0
# 8531                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 8536               Hero Glamour i3s 125cc  75000.0    Gurgaon      7488.0
# 8796                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 9322            TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner  age  power brand_name
# ...

# %%
second=df[(df['charges']<=100000) & (df['age']<=2)&(df['brand_name']=='Bajaj')&(df['owner']=='First Owner')]
second
# Out:
#                              bike_name  charges        city  kms_driven  \
# 95                  Bajaj Pulsar 150cc  60000.0        Pune      2000.0
# 340        Bajaj Pulsar 125cc Disc CBS  47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220  95000.0       Delhi     11000.0
# 510                 Bajaj Pulsar 150cc  66000.0       Delhi     15000.0
# 619           Bajaj V15 150cc POWER UP  35000.0      Mumbai     26000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS  85000.0    Balaghat      2500.0
# 1340         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1401                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1423                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1445         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1818             Bajaj CT 100 ES Alloy  39000.0   Faridabad      2564.0
# 1819     Bajaj Platina  Alloy ES-100cc  39000.0   Faridabad     12193.0
# ...

# %%
second['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj    41
# Name: count, dtype: int64

# %%
catgorical=df.select_dtypes(include="O")
catgorical.head(4)
# Out:
#                             bike_name       city        owner     brand_name
# 0  TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1         Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                TVS Apache RTR 180cc  Bangalore  First Owner            TVS

# %%
numeical=df.select_dtypes(exclude='O')
numeical.head(5)
# Out:
#     charges  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
combined=pd.concat([catgorical,numeical],axis='columns')
combined.head()
# Out:
#                               bike_name       city        owner  \
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1           Royal Enfield Classic 350cc      Delhi  First Owner
# 2                  Triumph Daytona 675R      Delhi  First Owner
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
#
#       brand_name   charges  kms_driven  age  power
# 0            TVS   35000.0     17654.0  3.0  110.0
# 1  Royal Enfield  119900.0     11000.0  4.0  350.0
# 2        Triumph  600000.0       110.0  8.0  675.0
# 3            TVS   65000.0     16329.0  4.0  180.0
# 4         Yamaha   80000.0     10000.0  3.0  150.0

# %%
catgorical.shape
# Out:
# (32648, 4)

# %%
numeical.shape
# Out:
# (32648, 4)

# %%
df.drop(['bike_name'],axis='columns')
# Out:
#         charges       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#           brand_name
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['new_value']='good'
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['fake']=df["bike_name"]+"good"
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop(['fake','new_value'],axis='columns',inplace=True)

# %%
df
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['brand_name']=='KTM'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643    False
# 32644    False
# 32645    False
# 32646    False
# 32647    False
# Name: brand_name, Length: 32648, dtype: bool

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                  bike_name   charges       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power       brand_name
# ...

# %%
combined.duplicated().sum()
# Out:
# np.int64(25324)

# %%
combined[combined.duplicated()].head()
# Out:
#                           bike_name       city        owner     brand_name  \
# 19              Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20           Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21           Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25               Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90  Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
#
#      charges  kms_driven  age  power
# 19   29900.0     20000.0  7.0  125.0
# 20  120000.0     23000.0  3.0  200.0
# 21   48000.0     24725.0  5.0  150.0
# 25   78000.0      9900.0  4.0  200.0
# 90   71800.0     43500.0  7.0  350.0

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
combined.duplicated().sum()
# Out:
# np.int64(25324)

# %%
combined[combined.duplicated()].head()
# Out:
#                           bike_name       city        owner     brand_name  \
# 19              Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20           Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21           Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25               Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90  Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
#
#      charges  kms_driven  age  power
# 19   29900.0     20000.0  7.0  125.0
# 20  120000.0     23000.0  3.0  200.0
# 21   48000.0     24725.0  5.0  150.0
# 25   78000.0      9900.0  4.0  200.0
# 90   71800.0     43500.0  7.0  350.0

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df2=df[(df['brand_name']=='KTM') |(df['brand_name']=='Suzuki') |(df['brand_name']=='Jawa')]
df2
# Out:
#                              bike_name   charges       city  kms_driven  \
# 17              Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                        KTM RC 390cc  180000.0       Pune     17700.0
# 35                      KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                    KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# 49    Suzuki Gixxer SF Fi 150cc SP ABS   97000.0      Delhi      4400.0
# ...                                ...       ...        ...         ...
# 9195                    KTM Duke 200cc   70000.0      Thane     49347.0
# 9255                    KTM Duke 125cc  135000.0  Bangalore      1050.0
# 9281  Suzuki Gixxer SF 150cc Rear Disc   63000.0  Bangalore     19100.0
# 9282                    KTM Duke 390cc  139100.0      Delhi     25500.0
# 9348                    KTM Duke 390cc  195000.0     Mumbai      4568.0
#
#              owner  age  power brand_name
# 17     First Owner  5.0  150.0     Suzuki
# ...

# %%
list=['KTM','Suzuki','Jawa']
filter_df=df[df['brand_name'].isin(list)]
filter_df
# Out:
#                              bike_name   charges       city  kms_driven  \
# 17              Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 33                        KTM RC 390cc  180000.0       Pune     17700.0
# 35                      KTM Duke 200cc   70000.0     Nashik    100000.0
# 39                    KTM RC 200cc ABS  179000.0  Bangalore      3400.0
# 49    Suzuki Gixxer SF Fi 150cc SP ABS   97000.0      Delhi      4400.0
# ...                                ...       ...        ...         ...
# 9195                    KTM Duke 200cc   70000.0      Thane     49347.0
# 9255                    KTM Duke 125cc  135000.0  Bangalore      1050.0
# 9281  Suzuki Gixxer SF 150cc Rear Disc   63000.0  Bangalore     19100.0
# 9282                    KTM Duke 390cc  139100.0      Delhi     25500.0
# 9348                    KTM Duke 390cc  195000.0     Mumbai      4568.0
#
#              owner  age  power brand_name
# 17     First Owner  5.0  150.0     Suzuki
# ...

# %%
city=['Mumbai','Pune','Nashik','jaipur']
filterdf=df[df['city'].isin(city)]['city'].value_counts()
filterdf
# Out:
# city
# Mumbai    609
# Pune      394
# Nashik     12
# Name: count, dtype: int64

# %%
df
# Out:
#                                  bike_name   charges       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power       brand_name
# ...

# %%
mumbai=df[df['city']=='Mumbai']
mumbai
# Out:
#                    bike_name   charges    city  kms_driven         owner  \
# 17    Suzuki Gixxer SF 150cc   48000.0  Mumbai     24725.0   First Owner
# 18        Benelli 302R 300CC  240000.0  Mumbai     15025.0  Second Owner
# 48           Hero Hunk 150cc   37000.0  Mumbai     10800.0   First Owner
# 52      TVS Apache RTR 160cc   60000.0  Mumbai     30000.0   First Owner
# 55      Benelli TNT 600i ABS  475000.0  Mumbai     11500.0  Second Owner
# ...                      ...       ...     ...         ...           ...
# 9258    Honda CB Unicorn 160   65000.0  Mumbai     18000.0   First Owner
# 9306      Bajaj Pulsar AS150   60000.0  Mumbai      4150.0   First Owner
# 9313         Bajaj V15 150cc   42000.0  Mumbai     16539.0   First Owner
# 9347    Bajaj Discover 125cc   14000.0  Mumbai     39211.0   First Owner
# 9348          KTM Duke 390cc  195000.0  Mumbai      4568.0   First Owner
#
#        age  power brand_name
# 17     5.0  150.0     Suzuki
# 18     3.0  302.0    Benelli
# ...

# %%
mum=mumbai['brand_name']=='KTM'
mum
# Out:
# 17      False
# 18      False
# 48      False
# 52      False
# 55      False
#         ...
# 9258    False
# 9306    False
# 9313    False
# 9347    False
# 9348     True
# Name: brand_name, Length: 609, dtype: bool

# %%
mum.value_counts()
# Out:
# brand_name
# False    538
# True      71
# Name: count, dtype: int64

# %%
brandls2=['KTM','TVS','Suzuki']
mumbai_bikes=mumbai[mumbai['brand_name'].isin(brandls2)]
mumbai_bikes.shape
# Out:
# (115, 8)

# %%
df
# Out:
#                                  bike_name   charges       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power       brand_name
# ...

# %%
power_200=mumbai_bikes[mumbai_bikes['power']<=200].shape
power_200
# Out:
# (67, 8)

# %%
power_200[(power_200['owner']=="First Owner") & (power_200['age']<=2) & (power_200['charges']<=70000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 power_200[(power_200['owner']=="First Owner") & (power_200['age']<=2) & (power_200['charges']<=70000)]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
mumbai.sort_values(by="charges")
# Out:
#                           bike_name    charges    city  kms_driven  \
# 321                 Hero Hunk 150cc    10000.0  Mumbai     21389.0
# 5011             Bajaj CT 100 100cc    10000.0  Mumbai     37066.0
# 8669             Bajaj Pulsar 150cc    10000.0  Mumbai     27228.0
# 6741           Bajaj Discover 125cc    12000.0  Mumbai     44004.0
# 8003             Bajaj Pulsar 150cc    12000.0  Mumbai     82000.0
# ...                             ...        ...     ...         ...
# 124        Ducati 1299 Superleggera   800000.0  Mumbai         3.0
# 2300         Suzuki Hayabusa 1300cc   950000.0  Mumbai       312.0
# 8401                 Kawasaki Z1000  1100000.0  Mumbai      6000.0
# 92    Ducati Scrambler 1100 Special  1350000.0  Mumbai       190.0
# 8591           Yamaha YZF-R1 1000cc  1450000.0  Mumbai       340.0
#
#              owner   age   power brand_name
# 321    First Owner  12.0   150.0       Hero
# 5011  Second Owner  16.0   100.0      Bajaj
# ...

# %%
delhi=df[df['city']=="Delhi"]
delhi
# Out:
#                                  bike_name   charges   city  kms_driven  \
# 1              Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# ...                                    ...       ...    ...         ...
# 9336                   Yamaha YZF-R3 320cc  220000.0  Delhi      7130.0
# 9338         Royal Enfield Himalayan 410cc  138000.0  Delhi      5000.0
# 9340                Honda CB Trigger 150cc   34400.0  Delhi     24513.0
# 9344  Royal Enfield Bullet Twinspark 350cc   80000.0  Delhi     56968.0
# 9362             Hero Hunk Rear Disc 150cc   25000.0  Delhi     48587.0
#
#              owner  age  power     brand_name
# 1      First Owner  4.0  350.0  Royal Enfield
# ...

# %%
delhi_top10=delhi.sort_values(by='charges')
delhi_top10.head(10)
# Out:
#                   bike_name  charges   city  kms_driven         owner   age  \
# 9194    Hero Ambition 135cc   5000.0  Delhi     82178.0   First Owner  18.0
# 4922     Bajaj Pulsar 150cc   6400.0  Delhi    100000.0   First Owner  18.0
# 4923     Bajaj Pulsar 150cc   6700.0  Delhi     81000.0   First Owner  17.0
# 4656   Bajaj Discover 125cc   8000.0  Delhi     21493.0   First Owner  16.0
# 4927  Hero CBZ Xtreme 150cc   9000.0  Delhi     62135.0  Second Owner  13.0
# 3121    TVS Star City 110cc   9000.0  Delhi     72302.0   First Owner  15.0
# 4726     Bajaj CT 100 100cc   9000.0  Delhi     50000.0   First Owner  16.0
# 6701     Bajaj Pulsar 150cc   9500.0  Delhi     50000.0   First Owner  16.0
# 7594     Bajaj Pulsar 150cc  10000.0  Delhi      1223.0   First Owner  13.0
# 437        TVS Apache 150cc  10200.0  Delhi     71474.0   First Owner  12.0
#
#       power brand_name
# 9194  135.0       Hero
# 4922  150.0      Bajaj
# 4923  150.0      Bajaj
# 4656  125.0      Bajaj
# ...

# %%
delhi_top10['brand_name'].value_counts()
# Out:
# brand_name
# Bajaj              380
# Royal Enfield      305
# Hero               207
# Yamaha             145
# TVS                112
# Honda               95
# Suzuki              54
# KTM                 52
# Harley-Davidson     24
# Hyosung             12
# Mahindra            10
# Triumph              8
# Benelli              6
# Kawasaki             6
# Ducati               5
# BMW                  3
# Rajdoot              1
# MV                   1
# Name: count, dtype: int64

# %%
delhi_top10 .to_csv('delhi_top10.csv',index=False)

# %%
df.head(10)
# Out:
#                                   bike_name   charges       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power     brand_name
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.isnull().sum()
# Out:
# bike_name     0
# charges       0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand_name    0
# dtype: int64

# %%
import numpy as np

# %%
dt={'A':[1,2,4,np.nan,5],'B':[6,7,np.nan,9,2],'C':[np.nan,2,3,8,9],'D':[4,3,5,6,7]}
dt
# Out:
# {'A': [1, 2, 4, nan, 5],
#  'B': [6, 7, nan, 9, 2],
#  'C': [nan, 2, 3, 8, 9],
#  'D': [4, 3, 5, 6, 7]}

# %%
dataframe=pd.DataFrame(dt)
dataframe
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
dataframe.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# D    0
# dtype: int64

# %%
dataframe.dropna(axis='columns')
# Out:
#    D
# 0  4
# 1  3
# 2  5
# 3  6
# 4  7

# %%
dataframe.dropna()
# Out:
#      A    B    C  D
# 1  2.0  7.0  2.0  3
# 4  5.0  2.0  9.0  7

# %%
dataframe.fillna(1)
# Out:
#      A    B    C  D
# 0  1.0  6.0  1.0  4
# 1  2.0  7.0  2.0  3
# 2  4.0  1.0  3.0  5
# 3  1.0  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
dataframe['A'].fillna(1)
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    1.0
# 4    5.0
# Name: A, dtype: float64

# %%
dataframe['B']
# Out:
# 0    6.0
# 1    7.0
# 2    NaN
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
dataframe['B'].fillna(dataframe['B'].mean())
# Out:
# 0    6.0
# 1    7.0
# 2    6.0
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
df=pd.read_csv('Used_Bikes.csv').head()
df
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df['price'].max()
# Out:
# np.float64(600000.0)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
group=df.groupby('brand')
group

# %%
max=group[['price']].max()
max
# Out:
#                   price
# brand
# Royal Enfield  119900.0
# TVS             65000.0
# Triumph        600000.0
# Yamaha          80000.0

# %%
min=group[['price']].min()
min
# Out:
#                   price
# brand
# Royal Enfield  119900.0
# TVS             35000.0
# Triumph        600000.0
# Yamaha          80000.0

# %%
min.columns
# Out:
# Index(['price'], dtype='object')

# %%
min.index
# Out:
# Index(['Royal Enfield', 'TVS', 'Triumph', 'Yamaha'], dtype='object', name='brand')

# %%
min.reset_index()
# Out:
#            brand     price
# 0  Royal Enfield  119900.0
# 1            TVS   35000.0
# 2        Triumph  600000.0
# 3         Yamaha   80000.0
