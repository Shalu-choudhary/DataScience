# %% [markdown]
# <h2>SEABORN</h2>

# %%
# import seaborn as sb

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns=['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'member']

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  member
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 1         10.34  1.66    Male     No   Sun  Dinner       3
# 2         21.01  3.50    Male     No   Sun  Dinner       3
# 3         23.68  3.31    Male     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# ..          ...   ...     ...    ...   ...     ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 241       22.67  2.00    Male    Yes   Sat  Dinner       2
# 242       17.82  1.75    Male     No   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [244 rows x 7 columns]

# %% [markdown]
# <p> Two function are used for create chart --><br>
# 1) relplot  2) catplot() <br>
# relplot-->relational plot is used when columns are numerical . it show scatter plot bydefault<br> from kind parameter we can change graph from scatter to the LINE PLOT <br>
# catplot---> catgorical plot is used when one column is catgorical and one columns is numerical<br>
# sns.lineplot()<br>
# sns.boxplot()<br>
# sns.countplot()<br>
# sns.barplot()<br>
# sns.scatterplot()<br>
# sns.histplot()</p>

# %%
# sns.lineplot()
# sns.boxplot()
# sns.countplot()
# sns.barplot()
# sns.scatterplot()
# sns.histplot()

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,kind='line')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker')
plt.show()
#hue---> add extra info(col)

# %%
#col--->> for seprating
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker',col='gender')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker',col='time')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',col='day')
plt.show()

# %%
female=df[df['gender']=='Female']

# %%
sns.relplot(x='tip',y='total_bill',data=female)

# %%
sns.relplot(x='total_bill',y='tip',data=female,hue='smoker',col='smoker')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=female,hue='smoker',row='day')
plt.show()

# %% [markdown]
# <h3> data visulization</h3>
# <p> univariate analysis--> from one chart<br> bivariate analysis---> from two chart <br> multivariate analysis---> from more than one chart</p>

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
# for warning
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(x='day',data=df,hue='gender')
plt.show()

# %%
sns.countplot(x='day',data=df,hue='gender',color='red')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df)

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')
plt.show()

# %%
sns.catplot(y='total_bill',data=df,kind='count')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='boxen')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='point')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='box')

# %% [markdown]
# <h3>Assignment</h3>
# df2=sns.load_dataset('titanic')<br>
# df2

# %%
df2=sns.load_dataset("titanic")
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df2.columns=['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
       'embarked', 'class', 'male/female', 'adult_male', 'deck', 'embark_town',
       'alive', 'alone']

# %%
df2
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df2.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#   male/female  adult_male deck  embark_town alive  alone
# 0         man        True  NaN  Southampton    no  False
# 1       woman       False    C    Cherbourg   yes  False
# 2       woman       False  NaN  Southampton   yes   True
# 3       woman       False    C  Southampton   yes  False
# 4         man        True  NaN  Southampton    no   True

# %%
sns.relplot(x='survived',y='age',data=df2)
plt.show()

# %%
sns.relplot(x='survived',y='age',data=df2,hue='gender',style='male/female',col='male/female')
plt.show()

# %%
sns.relplot(x='survived',y='age',data=df2,hue='gender',style='male/female',col='male/female',kind='line')
plt.show()

# %%
female=df2[df2['gender']=='female']

# %%
sns.relplot(x='survived',y='age',data=female)
plt.show()

# %%
female.value_counts().sum()
# Out:
# np.int64(88)

# %%
sns.relplot(x='survived',y='age',data=female,hue='gender',col='male/female')
plt.show()

# %%
df2['alive'].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
sns.countplot(df2['alive'],color='r',ec='k',lw=2,width=0.5)
# Out:
# <Axes: xlabel='count', ylabel='alive'>

# %%
filter=df2[(df2['gender']=='male')&(df2['age']>=35)]
filter.value_counts().sum()
# Out:
# np.int64(59)

# %%
sns.catplot(x='alive',y='sibsp',data=filter,hue='alive',col='alive')

plt.show()

# %% [markdown]
# <h3> Machine learning</h3><p> ML is pridict the future data based on the past data</p>
