# %% [markdown]
# # Pandas library--->
# <h4> it is a module and deal with different  type of data. It is specially used for deal with structured data. ex-sql,excel,.csv</h4>
# <h4> Type of Data :</h4>
# <p> structure  - tabular format<br>
#     unstructure<br>
#     semi structure<br></p>

# %%
import pandas as pd
print("import")
# Out:
# import

# %%
# 1d array== 1 series
# multiple series are called data frame(like spredsheet then convert it into table or schema from sql)
# use dictionary

# %%
dt={"name":['shalu','vanshika','ayush','piyush'],"branch":["cse",'it','eee','eca'],"class":[1,2,3,4],"city":["ajmer",'jaipur','udaipur','jodhpur']}
dt
# Out:
# {'name': ['shalu', 'vanshika', 'ayush', 'piyush'],
#  'branch': ['cse', 'it', 'eee', 'eca'],
#  'class': [1, 2, 3, 4],
#  'city': ['ajmer', 'jaipur', 'udaipur', 'jodhpur']}

# %% [markdown]
# <h3> Creating DataFrame by using Pandas </h3>

# %%
dict=pd.DataFrame(dt)     # organized in tabular form 
                          # keys are converted into coloumn / attributes
dict
# Out:
#        name branch  class     city
# 0     shalu    cse      1    ajmer
# 1  vanshika     it      2   jaipur
# 2     ayush    eee      3  udaipur
# 3    piyush    eca      4  jodhpur

# %%
type(dict)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h4> Access single column</h4>

# %%
dict['name']       # its called series one single col
# Out:
# 0       shalu
# 1    vanshika
# 2       ayush
# 3      piyush
# Name: name, dtype: object

# %%
type(dict['name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# <h4> Read the csv file </h4>

# %%
#csv files------>>>>>>
df=pd.read_csv('used_Bikes.csv')              #df-- data frame
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()   # it will return top 5 raws of the dataframe
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()   # it will return top last 5 raws of dataframe
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.head(10)          # 10 raws of the dataframe
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.info()   # it give information about the dataframe or record that is total no of raw / col etc
            # object is a catgorical value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# <h4> Accessing</h4>

# %%
#accessing---->>>>>>>>
# for single column give col name
# df.price    # one method of accessing single col in series
df['price']
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %% [markdown]
# <h4> Access price column </h4>

# %%
df[['price']]    # single col in the form of dataframe
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
# accessing more then one col in the form of matrix . jis order m input denge usi order m col print hoga
df[['price','city','brand']]
# Out:
#           price       city          brand
# 0       35000.0  Ahmedabad            TVS
# 1      119900.0      Delhi  Royal Enfield
# 2      600000.0      Delhi        Triumph
# 3       65000.0  Bangalore            TVS
# 4       80000.0  Bangalore         Yamaha
# ...         ...        ...            ...
# 32643   39000.0      Delhi           Hero
# 32644   30000.0     Karnal            TVS
# 32645   60000.0      Delhi          Bajaj
# 32646   15600.0     Jaipur           Hero
# 32647   22000.0       Pune          Bajaj
#
# [32648 rows x 3 columns]

# %% [markdown]
# <h4> LOC   <p> location (access specific row or column) </h4>

# %%
# Loc or iloc---> location
# accessing specific section from the df 
# df.loc[raw_index, column_labels]    labels are names
df.loc[101:111,['price','city','bike_name']]   # raw filter   start and end point are include
# Out:
#         price       city                            bike_name
# 101   80000.0  Bangalore                   Bajaj Pulsar RS200
# 102  135000.0  Bangalore          Royal Enfield Classic 350cc
# 103   11100.0       Pune                   Bajaj Pulsar 150cc
# 104  480000.0     Mumbai                     Benelli TNT 600i
# 105   65000.0   Thrissur     Suzuki Gixxer 150cc SP Rear Disc
# 106   60000.0  Bangalore              Yamaha FZ S V 2.0 150cc
# 107   80000.0  Bangalore                 Honda CBR 150R 150cc
# 108   46000.0      Delhi  Hero Splendor Plus Self Alloy 100cc
# 109   95000.0  Bangalore          Royal Enfield Classic 500cc
# 110  400000.0      Delhi                       Hyosung GT650R
# 111   55000.0  Bangalore                      Bajaj V15 150cc

# %%
df.loc[20:35,['owner','power','age','brand']]
# Out:
#            owner  power   age          brand
# 20   First Owner  200.0   3.0          Bajaj
# 21   First Owner  150.0   5.0         Suzuki
# 22   First Owner  110.0   2.0           Hero
# 23   First Owner  500.0   5.0  Royal Enfield
# 24   First Owner  150.0   6.0         Yamaha
# 25   First Owner  200.0   4.0          Bajaj
# 26   First Owner  125.0  16.0           Hero
# 27  Second Owner  125.0   7.0          Honda
# 28   First Owner  150.0   8.0          Bajaj
# 29   First Owner  160.0   2.0          Honda
# 30   First Owner  200.0   3.0          Bajaj
# 31  Second Owner  150.0   4.0         Yamaha
# 32   First Owner  220.0   6.0          Bajaj
# 33   First Owner  390.0   4.0            KTM
# 34   First Owner  150.0   8.0          Honda
# 35  Second Owner  200.0   8.0            KTM

# %%
#iloc :--->>>>
#df.iloc[raw index, column index]       in the form of df

# %%
df.iloc[20:35,3:8]
# Out:
#     kms_driven         owner   age  power          brand
# 20     23000.0   First Owner   3.0  200.0          Bajaj
# 21     24725.0   First Owner   5.0  150.0         Suzuki
# 22      3500.0   First Owner   2.0  110.0           Hero
# 23     24520.0   First Owner   5.0  500.0  Royal Enfield
# 24     23000.0   First Owner   6.0  150.0         Yamaha
# 25      9900.0   First Owner   4.0  200.0          Bajaj
# 26     29305.0   First Owner  16.0  125.0           Hero
# 27     30500.0  Second Owner   7.0  125.0          Honda
# 28     19000.0   First Owner   8.0  150.0          Bajaj
# 29      9100.0   First Owner   2.0  160.0          Honda
# 30     21914.0   First Owner   3.0  200.0          Bajaj
# 31     20000.0  Second Owner   4.0  150.0         Yamaha
# 32     15000.0   First Owner   6.0  220.0          Bajaj
# 33     17700.0   First Owner   4.0  390.0            KTM
# 34     30000.0   First Owner   8.0  150.0          Honda

# %%
df.iloc[:4,:5]  # end point not inclusive like in this 5th raw are not include
# Out:
#                             bike_name     price       city  kms_driven  \
# 0  TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1         Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
#
#          owner
# 0  First Owner
# 1  First Owner
# 2  First Owner
# 3  First Owner

# %%
df.price.max()          # return maximum price  from the price column of dataframe
# Out:
# np.float64(1900000.0)

# %%
df['price'].min()        # return minimum price
# Out:
# np.float64(4400.0)

# %%
df['price'].median()    #std(), # var()
# Out:
# np.float64(43000.0)

# %% [markdown]
# <h4> columns of dataframe</h4>

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
# for change the col name

df.columns=[['bike_names', 'price', 'city', 'kms_driven', 'owner', 'bike_age', 'power',
       'brand']]

# %%
df.head(3)
# Out:
#                            bike_names     price       city kms_driven  \
# 0  TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad    17654.0
# 1         Royal Enfield Classic 350cc  119900.0      Delhi    11000.0
# 2                Triumph Daytona 675R  600000.0      Delhi      110.0
#
#          owner bike_age  power          brand
# 0  First Owner      3.0  110.0            TVS
# 1  First Owner      4.0  350.0  Royal Enfield
# 2  First Owner      8.0  675.0        Triumph

# %%
# for check data type of col.
df.dtypes        # in numpy where dtype used in this dtypes is used
# Out:
# bike_names     object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# bike_age      float64
# power         float64
# brand          object
# dtype: object

# %%
# filter the data whose bikeprice is less than 50k

# df['price']<=50000   # return true or false on the condition satisfy
under_50k=df[df['price']<=50000]
under_50k.head()
# Out:
#   bike_names    price city kms_driven owner bike_age power brand
# 0        NaN  35000.0  NaN        NaN   NaN      NaN   NaN   NaN
# 1        NaN      NaN  NaN        NaN   NaN      NaN   NaN   NaN
# 2        NaN      NaN  NaN        NaN   NaN      NaN   NaN   NaN
# 3        NaN      NaN  NaN        NaN   NaN      NaN   NaN   NaN
# 4        NaN      NaN  NaN        NaN   NaN      NaN   NaN   NaN

# %%
df=pd.read_csv('used_Bikes.csv')  
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
under_50k=df[df['price']<=50000]
under_50k.head()
# Out:
#                               bike_name    price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7   Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                  Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                  Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17               Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
#
#           owner  age  power   brand
# 0   First Owner  3.0  110.0     TVS
# 7   First Owner  3.0  100.0    Hero
# 13  First Owner  8.0  100.0   Bajaj
# 14  First Owner  7.0  125.0   Bajaj
# 17  First Owner  5.0  150.0  Suzuki

# %%
under_50k['price'].max()   # return the max price from under_50k
# Out:
# np.float64(50000.0)

# %%
under_50k['brand'].value_counts()   # counts the total occurance of each unique value in a column
# Out:
# brand
# Bajaj            7143
# Hero             6258
# Yamaha           2250
# Suzuki           1295
# Honda            1178
# TVS               936
# Mahindra           31
# Royal Enfield      22
# LML                 1
# Name: count, dtype: int64

# %%
under_50k
# Out:
#                                  bike_name    price         city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0        Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0        Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0        Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0       Mumbai     24725.0
# ...                                    ...      ...          ...         ...
# 32642                   Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643               Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power   brand
# ...

# %%
under_50k['owner'].value_counts()
# Out:
# owner
# First Owner             17447
# Second Owner             1604
# Third Owner                57
# Fourth Owner Or More        6
# Name: count, dtype: int64

# %%
# for only first owner
first=under_50k[under_50k['owner']=="First Owner"]
first
# Out:
#                                  bike_name    price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17                  Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
# ...                                    ...      ...        ...         ...
# 32640               Hero Passion Pro 100cc  32000.0      Delhi     12000.0
# 32643               Hero Passion Pro 100cc  39000.0      Delhi     22000.0
# 32644                 TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32646            Hero Super Splendor 125cc  15600.0     Jaipur     84186.0
# 32647                   Bajaj Pulsar 150cc  22000.0       Pune     60857.0
#
#              owner   age  power   brand
# ...

# %%
first["price"].min()
# Out:
# np.float64(4400.0)

# %%
first['brand'].value_counts()
# Out:
# brand
# Bajaj            6356
# Hero             5541
# Yamaha           2187
# Suzuki           1286
# Honda            1131
# TVS               905
# Mahindra           27
# Royal Enfield      13
# LML                 1
# Name: count, dtype: int64

# %% [markdown]
# <h4>unique---></h4> <p>return unique value of column in the form of array</p>
# <h4>nunique---></h4> <p>return total no. of unique value</p>

# %%
first['brand'].unique()  # return name of unique brand
# Out:
# array(['TVS', 'Hero', 'Bajaj', 'Suzuki', 'Yamaha', 'Honda', 'Mahindra',
#        'Royal Enfield', 'LML'], dtype=object)

# %%
first['brand'].nunique()  # count the no of unique brand
# Out:
# 9

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].nunique()
# Out:
# 23

# %%
# conditions-->
# price  < 1 lakh
# owner == first owner
#  age<2 year

df[(df['price']<=100000)&(df["owner"]=="First Owner")& (df['age']<=2)]
# Out:
#                                 bike_name    price       city  kms_driven  \
# 22    Hero Splendor iSmart Plus IBS 110cc  46500.0      Delhi      3500.0
# 29                Honda X-Blade 160CC ABS  81200.0     Mettur      9100.0
# 47             Mahindra Centuro NXT 110cc  28000.0     Jaipur     45000.0
# 95                     Bajaj Pulsar 150cc  60000.0       Pune      2000.0
# 96             Suzuki Gixxer Fi 150cc ABS  96700.0   Vadodara      5100.0
# ...                                   ...      ...        ...         ...
# 8335              Bajaj Pulsar 150cc Neon  72000.0       Pune      3162.0
# 8531                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 8536               Hero Glamour i3s 125cc  75000.0    Gurgaon      7488.0
# 8796                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 9322            TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner  age  power     brand
# ...

# %%
second=df[(df['price']<=100000)&(df["owner"]=="First Owner")& (df['age']<=2)&(df['brand']=='Bajaj')]
second
# Out:
#                              bike_name    price        city  kms_driven  \
# 95                  Bajaj Pulsar 150cc  60000.0        Pune      2000.0
# 340        Bajaj Pulsar 125cc Disc CBS  47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220  95000.0       Delhi     11000.0
# 510                 Bajaj Pulsar 150cc  66000.0       Delhi     15000.0
# 619           Bajaj V15 150cc POWER UP  35000.0      Mumbai     26000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS  85000.0    Balaghat      2500.0
# 1340         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1401                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1423                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1445         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1818             Bajaj CT 100 ES Alloy  39000.0   Faridabad      2564.0
# 1819     Bajaj Platina  Alloy ES-100cc  39000.0   Faridabad     12193.0
# ...

# %%
second['brand'].value_counts()
# Out:
# brand
# Bajaj    41
# Name: count, dtype: int64

# %%
second.shape   # return total no. of rows and columns
# Out:
# (41, 8)

# %%
df=pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
#select numerical or categorical(string) value
# O means----> select those column whose data type are object
catgorical=df.select_dtypes(include='O')
catgorical.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
# for numerical value
# exclude--> except object data type 
numerical=df.select_dtypes(exclude="O")
numerical.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
# combined the columns axis='column
# by default axis is row
combined_df=pd.concat([catgorical,numerical],axis='columns')
combined_df.head()
# Out:
#                               bike_name       city        owner  \
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1           Royal Enfield Classic 350cc      Delhi  First Owner
# 2                  Triumph Daytona 675R      Delhi  First Owner
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
#
#            brand     price  kms_driven  age  power
# 0            TVS   35000.0     17654.0  3.0  110.0
# 1  Royal Enfield  119900.0     11000.0  4.0  350.0
# 2        Triumph  600000.0       110.0  8.0  675.0
# 3            TVS   65000.0     16329.0  4.0  180.0
# 4         Yamaha   80000.0     10000.0  3.0  150.0

# %%
catgorical.shape
# Out:
# (32648, 4)

# %%
numerical.shape
# both are should be saame
# Out:
# (32648, 4)

# %%
# delete the column. show deleted column only for this time(temporary)
# if we print df again then it show df with bike name 
df.drop('bike_name',axis='columns')
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# for delete completly we use inplace = True it delete the column from the dataframe
df.drop('bike_name',axis='columns',inplace=True)

# %%
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df.drop(['price','age'],axis='columns')   # drop more then one column
# Out:
#             city  kms_driven        owner  power          brand
# 0      Ahmedabad     17654.0  First Owner  110.0            TVS
# 1          Delhi     11000.0  First Owner  350.0  Royal Enfield
# 2          Delhi       110.0  First Owner  675.0        Triumph
# 3      Bangalore     16329.0  First Owner  180.0            TVS
# 4      Bangalore     10000.0  First Owner  150.0         Yamaha
# ...          ...         ...          ...    ...            ...
# 32643      Delhi     22000.0  First Owner  100.0           Hero
# 32644     Karnal      6639.0  First Owner  180.0            TVS
# 32645      Delhi     20373.0  First Owner  220.0          Bajaj
# 32646     Jaipur     84186.0  First Owner  125.0           Hero
# 32647       Pune     60857.0  First Owner  150.0          Bajaj
#
# [32648 rows x 5 columns]

# %%
# adding column with scaler value(single)
# in machine learning column,feature,variable is same
df['dumy']='upflair'

# %%
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand     dumy
# 0                TVS  upflair
# 1      Royal Enfield  upflair
# 2            Triumph  upflair
# 3                TVS  upflair
# ...

# %%
df['fake_price']=df['price']+1000
df.head()
# feature engineering--> when we create a new col with the help of previous col it is called feature engineering
# Out:
#       price       city  kms_driven        owner  age  power          brand  \
# 0   35000.0  Ahmedabad     17654.0  First Owner  3.0  110.0            TVS
# 1  119900.0      Delhi     11000.0  First Owner  4.0  350.0  Royal Enfield
# 2  600000.0      Delhi       110.0  First Owner  8.0  675.0        Triumph
# 3   65000.0  Bangalore     16329.0  First Owner  4.0  180.0            TVS
# 4   80000.0  Bangalore     10000.0  First Owner  3.0  150.0         Yamaha
#
#       dumy  fake_price
# 0  upflair     36000.0
# 1  upflair    120900.0
# 2  upflair    601000.0
# 3  upflair     66000.0
# 4  upflair     81000.0

# %%
df.drop(['dumy','fake_price'],axis='columns',inplace=True)
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df['brand']=="ktm"
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (32648, 7)

# %% [markdown]
# <h4> Find-out duplicates from dataframe</h4>

# %%
# it return total no. of duplicate 

df.duplicated().sum()
# Out:
# np.int64(25328)

# %%
df.drop_duplicates(inplace=True)  # drop the duplicates
df
# Out:
#          price       city  kms_driven        owner  age  power  \
# 0      35000.0  Ahmedabad     17654.0  First Owner  3.0  110.0
# 1     119900.0      Delhi     11000.0  First Owner  4.0  350.0
# 2     600000.0      Delhi       110.0  First Owner  8.0  675.0
# 3      65000.0  Bangalore     16329.0  First Owner  4.0  180.0
# 4      80000.0  Bangalore     10000.0  First Owner  3.0  150.0
# ...        ...        ...         ...          ...  ...    ...
# 9362   25000.0      Delhi     48587.0  First Owner  8.0  150.0
# 9369   35000.0  Bangalore     60000.0  First Owner  9.0  220.0
# 9370  450000.0    Jodhpur      3430.0  First Owner  4.0  750.0
# 9371  139000.0  Hyderabad     21300.0  First Owner  4.0  400.0
# 9372   80000.0  Hyderabad      7127.0  First Owner  5.0  220.0
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...               ...
# 9362             Hero
# ...

# %%
df.shape
# Out:
# (7320, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
combined_df
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand     price  kms_driven   age  power
# 0                TVS   35000.0     17654.0   3.0  110.0
# ...

# %%
combined_df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
# for which are duplicate
combined_df[combined_df.duplicated()].head()
# Out:
#                           bike_name       city        owner          brand  \
# 19              Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20           Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21           Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25               Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90  Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
#
#        price  kms_driven  age  power
# 19   29900.0     20000.0  7.0  125.0
# 20  120000.0     23000.0  3.0  200.0
# 21   48000.0     24725.0  5.0  150.0
# 25   78000.0      9900.0  4.0  200.0
# 90   71800.0     43500.0  7.0  350.0

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1344
# Hero               1141
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              52
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
sh=df[(df['brand']=='KTM')|(df['brand']=='Suzuki')|(df['brand']=='jawa')]
sh
# Out:
#          price       city  kms_driven         owner  age  power   brand
# 17     48000.0     Mumbai     24725.0   First Owner  5.0  150.0  Suzuki
# 33    180000.0       Pune     17700.0   First Owner  4.0  390.0     KTM
# 35     70000.0     Nashik    100000.0  Second Owner  8.0  200.0     KTM
# 39    179000.0  Bangalore      3400.0   First Owner  2.0  200.0     KTM
# 49     97000.0      Delhi      4400.0   First Owner  3.0  150.0  Suzuki
# ...        ...        ...         ...           ...  ...    ...     ...
# 9195   70000.0      Thane     49347.0   First Owner  9.0  200.0     KTM
# 9255  135000.0  Bangalore      1050.0   First Owner  3.0  125.0     KTM
# 9281   63000.0  Bangalore     19100.0   First Owner  5.0  150.0  Suzuki
# 9282  139100.0      Delhi     25500.0   First Owner  5.0  390.0     KTM
# 9348  195000.0     Mumbai      4568.0   First Owner  4.0  390.0     KTM
#
# [578 rows x 7 columns]

# %%
#same as above code
brand_ls=['KTM','Suzuki','Jawa']
filter_df=df[df['brand'].isin(brand_ls)]  # isin() is a function which return the value if value present in the list
filter_df
# Out:
#          price       city  kms_driven         owner  age  power   brand
# 17     48000.0     Mumbai     24725.0   First Owner  5.0  150.0  Suzuki
# 33    180000.0       Pune     17700.0   First Owner  4.0  390.0     KTM
# 35     70000.0     Nashik    100000.0  Second Owner  8.0  200.0     KTM
# 39    179000.0  Bangalore      3400.0   First Owner  2.0  200.0     KTM
# 49     97000.0      Delhi      4400.0   First Owner  3.0  150.0  Suzuki
# ...        ...        ...         ...           ...  ...    ...     ...
# 9195   70000.0      Thane     49347.0   First Owner  9.0  200.0     KTM
# 9255  135000.0  Bangalore      1050.0   First Owner  3.0  125.0     KTM
# 9281   63000.0  Bangalore     19100.0   First Owner  5.0  150.0  Suzuki
# 9282  139100.0      Delhi     25500.0   First Owner  5.0  390.0     KTM
# 9348  195000.0     Mumbai      4568.0   First Owner  4.0  390.0     KTM
#
# [585 rows x 7 columns]

# %%
city_ls=['Mumbai','Nasik','Pune']
filter_df=df[df['city'].isin(city_ls)]
filter_df
# Out:
#          price    city  kms_driven         owner   age  power    brand
# 17     48000.0  Mumbai     24725.0   First Owner   5.0  150.0   Suzuki
# 18    240000.0  Mumbai     15025.0  Second Owner   3.0  302.0  Benelli
# 33    180000.0    Pune     17700.0   First Owner   4.0  390.0      KTM
# 48     37000.0  Mumbai     10800.0   First Owner   8.0  150.0     Hero
# 52     60000.0  Mumbai     30000.0   First Owner   5.0  160.0      TVS
# ...        ...     ...         ...           ...   ...    ...      ...
# 9313   42000.0  Mumbai     16539.0   First Owner   5.0  150.0    Bajaj
# 9342   55000.0    Pune      6138.0   First Owner   4.0  150.0   Yamaha
# 9347   14000.0  Mumbai     39211.0   First Owner  16.0  125.0    Bajaj
# 9348  195000.0  Mumbai      4568.0   First Owner   4.0  390.0      KTM
# 9349   55000.0    Pune     10000.0   First Owner   6.0  180.0    Bajaj
#
# [1001 rows x 7 columns]

# %%
city_ls=['Mumbai','Nashik','Pune','Jaipur']
filter_df=filter_df[df['city'].isin(city_ls)]['city'].value_counts()
filter_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9488\2046745704.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filter_df=filter_df[df['city'].isin(city_ls)]['city'].value_counts()
# city
# Mumbai    607
# Pune      394
# Name: count, dtype: int64

# %%
jaipur=df[df['city']=='Jaipur']
jaipur
# Out:
#          price    city  kms_driven         owner   age  power            brand
# 47     28000.0  Jaipur     45000.0   First Owner   2.0  110.0         Mahindra
# 134    47000.0  Jaipur     70000.0   First Owner   6.0  150.0           Suzuki
# 166   123600.0  Jaipur      7702.0   First Owner   3.0  350.0    Royal Enfield
# 189   435000.0  Jaipur      5550.0  Second Owner   7.0  883.0  Harley-Davidson
# 490    55000.0  Jaipur      2000.0   First Owner   9.0  150.0            Honda
# ...        ...     ...         ...           ...   ...    ...              ...
# 9161   41000.0  Jaipur      8000.0   First Owner   6.0  110.0         Mahindra
# 9187  520000.0  Jaipur       399.0   First Owner   2.0  750.0  Harley-Davidson
# 9197   90000.0  Jaipur     17000.0   First Owner   7.0  350.0    Royal Enfield
# 9198   83800.0  Jaipur     21540.0  Second Owner  10.0  350.0    Royal Enfield
# 9259   37000.0  Jaipur      8030.0   First Owner   4.0  110.0           Yamaha
#
# [299 rows x 7 columns]

# %%
JAI=jaipur['brand']=='KTM'
JAI.value_counts()
# Out:
# brand
# False    292
# True       7
# Name: count, dtype: int64

# %%
brand_ls=['KTM','TVS','Suzuki']
jaipurbikes=jaipur[jaipur['brand'].isin(brand_ls)]
jaipurbikes.shape
# Out:
# (40, 7)

# %%
bike_70k=jaipurbikes[jaipurbikes['price']<=70000].shape
bike_70k
# Out:
# (28, 7)

# %%
bike_70k=jaipurbikes[jaipurbikes['price']<=70000]
bike_70k
# Out:
#         price    city  kms_driven         owner   age  power   brand
# 134   47000.0  Jaipur     70000.0   First Owner   6.0  150.0  Suzuki
# 1304  63000.0  Jaipur      1639.0   First Owner   4.0  160.0     TVS
# 2302  19542.0  Jaipur     56592.0   First Owner   9.0  160.0     TVS
# 3364  30000.0  Jaipur     27000.0   First Owner   6.0  110.0     TVS
# 3904  51000.0  Jaipur     18314.0   First Owner   7.0  160.0     TVS
# 3907  47000.0  Jaipur     26000.0   First Owner   8.0  160.0     TVS
# 3920  26500.0  Jaipur      2342.0   First Owner   9.0  110.0     TVS
# 3922  26000.0  Jaipur     24000.0   First Owner   7.0  110.0     TVS
# 3936  70000.0  Jaipur     28112.0   First Owner   4.0  150.0  Suzuki
# 4063  33000.0  Jaipur     18677.0   First Owner   6.0  100.0     TVS
# 4371  68000.0  Jaipur     11123.0   First Owner   5.0  160.0     TVS
# 4607  23000.0  Jaipur     28895.0   First Owner   8.0  100.0     TVS
# 4851  45000.0  Jaipur     20431.0   First Owner   7.0  160.0     TVS
# ...

# %%
bike_70k[(bike_70k['owner']=='First Owner') & (bike_70k['age']<=2) & (bike_70k['power']<=180)]
# Out:
#         price    city  kms_driven        owner  age  power brand
# 7311  70000.0  Jaipur    207102.0  First Owner  2.0  180.0   TVS

# %%
# sort df with the col name in ascending order
jaipur.sort_values(by='price')
# Out:
#           price    city  kms_driven         owner   age   power  \
# 2696    14000.0  Jaipur     70756.0   First Owner  13.0   100.0
# 9029    14000.0  Jaipur     50000.0  Second Owner  19.0   100.0
# 3365    15000.0  Jaipur     52391.0   First Owner  15.0   125.0
# 2983    15000.0  Jaipur     48000.0   First Owner  17.0   100.0
# 4092    15244.0  Jaipur     40320.0   First Owner  15.0   125.0
# ...         ...     ...         ...           ...   ...     ...
# 189    435000.0  Jaipur      5550.0  Second Owner   7.0   883.0
# 2599   445600.0  Jaipur      1500.0   First Owner   5.0   750.0
# 7650   478000.0  Jaipur      1234.0   First Owner   3.0   650.0
# 9187   520000.0  Jaipur       399.0   First Owner   2.0   750.0
# 617   1260000.0  Jaipur     17000.0   First Owner   4.0  1300.0
#
#                 brand
# 2696             Hero
# 9029             Hero
# 3365             Hero
# 2983            Bajaj
# 4092             Hero
# ...               ...
# 189   Harley-Davidson
# ...

# %%
# SHIFT+ TAB PRESS FOR INFO TAB
# sort the value in descending order by the ascending=False
jaipur.sort_values(by='price',ascending=False)
# Out:
#           price    city  kms_driven         owner   age   power  \
# 617   1260000.0  Jaipur     17000.0   First Owner   4.0  1300.0
# 9187   520000.0  Jaipur       399.0   First Owner   2.0   750.0
# 7650   478000.0  Jaipur      1234.0   First Owner   3.0   650.0
# 2599   445600.0  Jaipur      1500.0   First Owner   5.0   750.0
# 189    435000.0  Jaipur      5550.0  Second Owner   7.0   883.0
# ...         ...     ...         ...           ...   ...     ...
# 4092    15244.0  Jaipur     40320.0   First Owner  15.0   125.0
# 2983    15000.0  Jaipur     48000.0   First Owner  17.0   100.0
# 3365    15000.0  Jaipur     52391.0   First Owner  15.0   125.0
# 9029    14000.0  Jaipur     50000.0  Second Owner  19.0   100.0
# 2696    14000.0  Jaipur     70756.0   First Owner  13.0   100.0
#
#                 brand
# 617            Suzuki
# 9187  Harley-Davidson
# 7650         Kawasaki
# 2599  Harley-Davidson
# 189   Harley-Davidson
# ...               ...
# 4092             Hero
# ...

# %%
print(jaipur.sort_values.__doc__)
# Out:
#         Sort by the values along either axis.
#
#         Parameters
#         ----------
#         by : str or list of str
#             Name or list of names to sort by.
#
#             - if `axis` is 0 or `'index'` then `by` may contain index
#               levels and/or column labels.
#             - if `axis` is 1 or `'columns'` then `by` may contain column
#               levels and/or index labels.
#         axis : "{0 or 'index', 1 or 'columns'}", default 0
#              Axis to be sorted.
#         ascending : bool or list of bool, default True
#              Sort ascending vs. descending. Specify list for multiple sort
#              orders.  If this is a list of bools, must match the length of
#              the by.
#         inplace : bool, default False
#              If True, perform operation in-place.
#         kind : {'quicksort', 'mergesort', 'heapsort', 'stable'}, default 'quicksort'
# ...

# %%
# delhi location top 10 bikes price higest

# %%
Delhi=df[df['city']=='Delhi']
Delhi
# Out:
#          price   city  kms_driven         owner  age  power          brand
# 1     119900.0  Delhi     11000.0   First Owner  4.0  350.0  Royal Enfield
# 2     600000.0  Delhi       110.0   First Owner  8.0  675.0        Triumph
# 5      53499.0  Delhi     25000.0   First Owner  6.0  150.0         Yamaha
# 6      85000.0  Delhi      8200.0   First Owner  3.0  160.0          Honda
# 7      45000.0  Delhi     12645.0   First Owner  3.0  100.0           Hero
# ...        ...    ...         ...           ...  ...    ...            ...
# 9336  220000.0  Delhi      7130.0   First Owner  5.0  320.0         Yamaha
# 9338  138000.0  Delhi      5000.0   First Owner  5.0  410.0  Royal Enfield
# 9340   34400.0  Delhi     24513.0  Second Owner  8.0  150.0          Honda
# 9344   80000.0  Delhi     56968.0   First Owner  8.0  350.0  Royal Enfield
# 9362   25000.0  Delhi     48587.0   First Owner  8.0  150.0           Hero
#
# [1424 rows x 7 columns]

# %%
delhi_top=Delhi.sort_values(by='price')
delhi_top
# Out:
#           price   city  kms_driven         owner   age   power   brand
# 9194     5000.0  Delhi     82178.0   First Owner  18.0   135.0    Hero
# 4922     6400.0  Delhi    100000.0   First Owner  18.0   150.0   Bajaj
# 4923     6700.0  Delhi     81000.0   First Owner  17.0   150.0   Bajaj
# 4656     8000.0  Delhi     21493.0   First Owner  16.0   125.0   Bajaj
# 3121     9000.0  Delhi     72302.0   First Owner  15.0   110.0     TVS
# ...         ...    ...         ...           ...   ...     ...     ...
# 6070  1350000.0  Delhi      4600.0   First Owner   3.0   850.0     BMW
# 6501  1490000.0  Delhi     12500.0   First Owner   5.0  1200.0  Ducati
# 3016  1500000.0  Delhi     18000.0   First Owner   4.0  1000.0     BMW
# 7671  1550000.0  Delhi      9800.0  Second Owner   6.0  1000.0  Yamaha
# 4864  1800000.0  Delhi      2600.0   First Owner   4.0  1000.0     BMW
#
# [1424 rows x 7 columns]

# %%
delhi_top.head(10)
# Out:
#         price   city  kms_driven         owner   age  power  brand
# 9194   5000.0  Delhi     82178.0   First Owner  18.0  135.0   Hero
# 4922   6400.0  Delhi    100000.0   First Owner  18.0  150.0  Bajaj
# 4923   6700.0  Delhi     81000.0   First Owner  17.0  150.0  Bajaj
# 4656   8000.0  Delhi     21493.0   First Owner  16.0  125.0  Bajaj
# 3121   9000.0  Delhi     72302.0   First Owner  15.0  110.0    TVS
# 4726   9000.0  Delhi     50000.0   First Owner  16.0  100.0  Bajaj
# 4927   9000.0  Delhi     62135.0  Second Owner  13.0  150.0   Hero
# 6701   9500.0  Delhi     50000.0   First Owner  16.0  150.0  Bajaj
# 7594  10000.0  Delhi      1223.0   First Owner  13.0  150.0  Bajaj
# 437   10200.0  Delhi     71474.0   First Owner  12.0  150.0    TVS

# %%
max_price=Delhi.sort_values(by='price',ascending=False).head(10)
max_price
# Out:
#           price   city  kms_driven         owner  age   power            brand
# 4864  1800000.0  Delhi      2600.0   First Owner  4.0  1000.0              BMW
# 7671  1550000.0  Delhi      9800.0  Second Owner  6.0  1000.0           Yamaha
# 3016  1500000.0  Delhi     18000.0   First Owner  4.0  1000.0              BMW
# 6501  1490000.0  Delhi     12500.0   First Owner  5.0  1200.0           Ducati
# 6070  1350000.0  Delhi      4600.0   First Owner  3.0   850.0              BMW
# 7481  1149000.0  Delhi      9875.0   First Owner  6.0  1300.0           Suzuki
# 7064  1100000.0  Delhi     24000.0   First Owner  4.0   107.0  Harley-Davidson
# 7595  1070500.0  Delhi       289.0   First Owner  3.0   959.0           Ducati
# 3007  1000000.0  Delhi      1500.0   First Owner  4.0  1200.0          Triumph
# 4725   950000.0  Delhi     21000.0   First Owner  8.0  1300.0           Suzuki

# %%
max_price.max()
# Out:
# price            1800000.0
# city                 Delhi
# kms_driven         24000.0
# owner         Second Owner
# age                    8.0
# power               1300.0
# brand               Yamaha
# dtype: object

# %%
max_price['brand'].value_counts()
# Out:
# brand
# BMW                3
# Ducati             2
# Suzuki             2
# Yamaha             1
# Harley-Davidson    1
# Triumph            1
# Name: count, dtype: int64

# %%
# for saving/sharing filtering data file/frame
max_price.to_csv('delhi_top10.csv',index=False)

# %%
#pandas/numpy  files

# %%
df=pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
#missing values  false-->no missing value, true-> missing value
# isnull() ---> for findout the missing value in the dataframe
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
import numpy as np

# %%
dt={'A':[1,2,4,np.nan,5],'B':[6,7,np.nan,9,2],'C':[np.nan,2,3,8,9],'D':[4,3,5,6,7]}
dt
# Out:
# {'A': [1, 2, 4, nan, 5],
#  'B': [6, 7, nan, 9, 2],
#  'C': [nan, 2, 3, 8, 9],
#  'D': [4, 3, 5, 6, 7]}

# %%
import pandas as pd

# %%
df=pd.DataFrame(dt)
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# D    0
# dtype: int64

# %% [markdown]
# <h4>missing value handling</h4>

# %%
# 1) remove the records
# 2) record fill
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
df.dropna(axis='columns') # row-0,col-1
#df=dropnan(axis=1)  # drop nun values col
# Out:
#    D
# 0  4
# 1  3
# 2  5
# 3  6
# 4  7

# %%
# remove the records 12%
df.dropna()    # drop nun value
# Out:
#      A    B    C  D
# 1  2.0  7.0  2.0  3
# 4  5.0  2.0  9.0  7

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
# 2) fill the record
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
df.fillna(1)  # fill same value at all nan place
# Out:
#      A    B    C  D
# 0  1.0  6.0  1.0  4
# 1  2.0  7.0  2.0  3
# 2  4.0  1.0  3.0  5
# 3  1.0  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
df['A'].fillna(1)    # fill data from fillna in a particular column
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    1.0
# 4    5.0
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %% [markdown]
# <h3>if col is numerical then fill mean  or median as a value<br> if column is  catgorical then fill mode(most repeated value)</h3>

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  6.0  NaN  4
# 1  2.0  7.0  2.0  3
# 2  4.0  NaN  3.0  5
# 3  NaN  9.0  8.0  6
# 4  5.0  2.0  9.0  7

# %%
df['B']
# Out:
# 0    6.0
# 1    7.0
# 2    NaN
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
df['B'].mean()
# Out:
# np.float64(6.0)

# %%
df['B'].fillna(df['B'].mean())
# Out:
# 0    6.0
# 1    7.0
# 2    6.0
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
df=pd.read_csv('Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# group by creation
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# <h4> groupby--> value for each and every column</h4>

# %%
# max price  for each and every brand vehicle
group=df.groupby('brand')

# %%
group

# %%
group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
min=group[['price']].min()
min
# Out:
#                     price
# brand
# BMW              255000.0
# Bajaj              6400.0
# Benelli          110700.0
# Ducati           380000.0
# Harley-Davidson  250000.0
# Hero               5000.0
# Honda             10000.0
# Hyosung          120000.0
# Ideal            100000.0
# Indian           700000.0
# Jawa             146000.0
# KTM               55000.0
# Kawasaki         110000.0
# LML                4400.0
# MV               950000.0
# Mahindra          17800.0
# Rajdoot           75000.0
# Royal Enfield     33500.0
# Suzuki             8000.0
# TVS                5800.0
# Triumph          500000.0
# Yamaha             9400.0
# Yezdi             68000.0

# %%
min[['price']].min()
# Out:
# price    4400.0
# dtype: float64

# %%
min.columns  # in this col is one
# Out:
# Index(['price'], dtype='object')

# %%
min.index   # return index
# Out:
# Index(['BMW', 'Bajaj', 'Benelli', 'Ducati', 'Harley-Davidson', 'Hero', 'Honda',
#        'Hyosung', 'Ideal', 'Indian', 'Jawa', 'KTM', 'Kawasaki', 'LML', 'MV',
#        'Mahindra', 'Rajdoot', 'Royal Enfield', 'Suzuki', 'TVS', 'Triumph',
#        'Yamaha', 'Yezdi'],
#       dtype='object', name='brand')

# %%
min.reset_index()
# Out:
#               brand     price
# 0               BMW  255000.0
# 1             Bajaj    6400.0
# 2           Benelli  110700.0
# 3            Ducati  380000.0
# 4   Harley-Davidson  250000.0
# 5              Hero    5000.0
# 6             Honda   10000.0
# 7           Hyosung  120000.0
# 8             Ideal  100000.0
# 9            Indian  700000.0
# 10             Jawa  146000.0
# 11              KTM   55000.0
# 12         Kawasaki  110000.0
# 13              LML    4400.0
# 14               MV  950000.0
# 15         Mahindra   17800.0
# 16          Rajdoot   75000.0
# 17    Royal Enfield   33500.0
# 18           Suzuki    8000.0
# 19              TVS    5800.0
# 20          Triumph  500000.0
# 21           Yamaha    9400.0
# 22            Yezdi   68000.0

# %%
# find out the min price brand with name or price

# %%
group['price'].agg(min_price='min',max_price='max',mean_price='mean')
# Out:
#                  min_price  max_price    mean_price
# brand
# BMW               255000.0  1800000.0  6.735000e+05
# Bajaj               6400.0   195000.0  4.903128e+04
# Benelli           110700.0   785000.0  2.983761e+05
# Ducati            380000.0  1500000.0  9.005750e+05
# Harley-Davidson   250000.0  1100000.0  4.734291e+05
# Hero                5000.0   104000.0  3.068307e+04
# Honda              10000.0   800000.0  5.147068e+04
# Hyosung           120000.0   493500.0  2.432084e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.884286e+05
# KTM                55000.0   860000.0  1.479469e+05
# Kawasaki          110000.0  1100000.0  4.167116e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.266667e+06
# Mahindra           17800.0   175000.0  7.005780e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['brand'].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
df['brand'].value_counts().values  # add this data to above
# Out:
# array([2081, 1346, 1142,  676,  651,  481,  375,  203,   91,   61,   53,
#          50,   46,   21,   20,   10,    7,    3,    3,    1,    1,    1,
#           1])

# %%
group.get_group("Honda")   # create a dataframe by using group
# Out:
#                           bike_name     price       city  kms_driven  \
# 6     Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 27          Honda CBF Stunner 125cc   20800.0  Faridabad     30500.0
# 29          Honda X-Blade 160CC ABS   81200.0     Mettur      9100.0
# 34           Honda CB Unicorn 150cc   40000.0      Noida     30000.0
# 37             Honda CBR 150R 150cc   65000.0  Allahabad     43000.0
# ...                             ...       ...        ...         ...
# 9250                 Honda CBR 250R   80000.0      Delhi      8000.0
# 9258           Honda CB Unicorn 160   65000.0     Mumbai     18000.0
# 9260      Honda CBR 250R Repsol ABS  120000.0      Noida     14000.0
# 9340         Honda CB Trigger 150cc   34400.0      Delhi     24513.0
# 9346           Honda CBR 150R 150cc   61483.0     Kanpur     28032.0
#
#              owner   age  power  brand
# 6      First Owner   3.0  160.0  Honda
# 27    Second Owner   7.0  125.0  Honda
# ...

# %%
group2=df.groupby('owner')
group2

# %%
group2.min()
# Out:
#                                 bike_name    price        city  kms_driven  \
# owner
# First Owner             BMW F750 GS 850cc   4400.0  24 Pargana         3.0
# Fourth Owner Or More  Bajaj Avenger 220cc  11000.0   Ahmedabad      2009.0
# Second Owner          Bajaj  Pulsar 180cc   7500.0  24 Pargana         1.0
# Third Owner           Bajaj Avenger 200cc   7000.0   Ahmedabad        23.0
#
#                       age  power  brand
# owner
# First Owner           1.0  100.0    BMW
# Fourth Owner Or More  4.0  100.0  Bajaj
# Second Owner          2.0  100.0  Bajaj
# Third Owner           4.0  100.0  Bajaj

# %%
group2['price'].min()
# Out:
# owner
# First Owner              4400.0
# Fourth Owner Or More    11000.0
# Second Owner             7500.0
# Third Owner              7000.0
# Name: price, dtype: float64

# %%
group2['price'].agg(min_price='min',max_price='max',mean_price='mean')
# Out:
#                       min_price  max_price    mean_price
# owner
# First Owner              4400.0  1900000.0  85044.934207
# Fourth Owner Or More    11000.0   141000.0  62699.000000
# Second Owner             7500.0  1550000.0  83653.561224
# Third Owner              7000.0   699000.0  83404.130952

# %%
# create a new dataframe in which aggregate function are its column
group2['price'].agg(min_price='min',max_price='max',mean_price='mean')
# Out:
#                       min_price  max_price    mean_price
# owner
# First Owner              4400.0  1900000.0  85044.934207
# Fourth Owner Or More    11000.0   141000.0  62699.000000
# Second Owner             7500.0  1550000.0  83653.561224
# Third Owner              7000.0   699000.0  83404.130952

# %%
bajaj=df[df['brand']=='Bajaj']
bajaj_grp=bajaj.groupby('owner')
bajaj_grp['price'].agg(min_price='min',max_price='max',mean_price='mean',)
# Out:
#                       min_price  max_price    mean_price
# owner
# First Owner              6400.0   195000.0  49915.159664
# Fourth Owner Or More    11000.0    37000.0  24000.000000
# Second Owner             9000.0   140000.0  41056.980769
# Third Owner              7000.0    85000.0  28565.736842

# %%
#map function---->>>>>

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
label={'First Owner':1,'Second Owner ':2,'Third Owner  ':3,'Fourth Owner':4}
label
# Out:
# {'First Owner': 1, 'Second Owner ': 2, 'Third Owner  ': 3, 'Fourth Owner': 4}

# %%
output=df['owner'].map(label)

# %%
df['owner']=output

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# ...

# %%
df['owner'].value_counts()
# Out:
# owner
# 1.0    6642
# Name: count, dtype: int64
